# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/AA1i3p68.jpg",1)

# %%
print(img[0][0][0])
# Out:
# 170

# %%
print(img.shape)

cv2_imshow(img)
# Out:
# (1080, 1711, 3)
# <PIL.Image.Image image mode=RGB size=1711x1080>

# %%
img = cv2.imread('/content/AA1i3p68.jpg', 0)
print(img.shape)
cv2_imshow(img)
# Out:
# (1080, 1711)
# <PIL.Image.Image image mode=L size=1711x1080>

# %%
img = cv2.imread('/content/AA1i3p68.jpg', -1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1711x1080>
