# %%
# !pip install pandas

# %%
# !pip install beautiful
# !pip install xlwt
# !pip install SQLAlchemy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 2.3 MB/s eta 0:00:00
# ...

# %%
# !pip install pytorch
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pytorch
#   Running setup.py clean for pytorch
# Failed to build pytorch
# ERROR: Could not build wheels for pytorch, which is required to install pyproject.toml-based projects

# %%
import pandas as pd

# %%
path = '/content/Churn_Modelling.csv'
df_Churn_Modelling_csv = pd.read_csv(path)
df_Churn_Modelling_csv
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_Churn_Modelling_csv.to_excel("/content/Churn_Modelling_xls.xls")

# %%
df_Churn_Modelling_csv.to_html("/content/Churn_Modelling_html.html")

# %%
df_Churn_Modelling_csv.to_json("/content/Churn_Modelling_json.json")

# %%
df_Churn_Modelling_csv.to_string("/content/Churn_Modelling_string.string")

# %%
df_Churn_Modelling_csv.to_xml ("/content/Churn_Modelling_string.string")

# %%
import sqlite3
conn = sqlite3.connect('test_database')

# %%
df_Churn_Modelling_csv.to_sql("df_Churn_Modelling_sql.sql", conn)
# Out:
# 10000

# %%
path = '/content/Churn_Modelling_json.json'
df_Churn_Modelling_json = pd.read_json(path)
df_Churn_Modelling_json
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
path = '/content/Churn_Modelling_html.html'
df_Churn_Modelling_html = pd.read_html(path)
df_Churn_Modelling_json
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
import pandas as pd
path = '/content/Churn_Modelling_xls.xlsx'
df_Churn_Modelling_xlsx = pd.read_excel(path)
df_Churn_Modelling_xlsx
# Out:
#       Unnamed: 0  RowNumber  CustomerId    Surname  CreditScore Geography  \
# 0              0          1    15634602   Hargrave          619    France
# 1              1          2    15647311       Hill          608     Spain
# 2              2          3    15619304       Onio          502    France
# 3              3          4    15701354       Boni          699    France
# 4              4          5    15737888   Mitchell          850     Spain
# ...          ...        ...         ...        ...          ...       ...
# 9995        9995       9996    15606229   Obijiaku          771    France
# 9996        9996       9997    15569892  Johnstone          516    France
# 9997        9997       9998    15584532        Liu          709    France
# 9998        9998       9999    15682355  Sabbatini          772   Germany
# 9999        9999      10000    15628319     Walker          792    France
#
#       Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# ...

# %%
path = '/content/Churn_Modelling_xls.xls'
df_Churn_Modelling_xls = pd.read_excel(path)
df_Churn_Modelling_xls
# Out:
#       Unnamed: 0  RowNumber  CustomerId    Surname  CreditScore Geography  \
# 0              0          1    15634602   Hargrave          619    France
# 1              1          2    15647311       Hill          608     Spain
# 2              2          3    15619304       Onio          502    France
# 3              3          4    15701354       Boni          699    France
# 4              4          5    15737888   Mitchell          850     Spain
# ...          ...        ...         ...        ...          ...       ...
# 9995        9995       9996    15606229   Obijiaku          771    France
# 9996        9996       9997    15569892  Johnstone          516    France
# 9997        9997       9998    15584532        Liu          709    France
# 9998        9998       9999    15682355  Sabbatini          772   Germany
# 9999        9999      10000    15628319     Walker          792    France
#
#       Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# ...

# %% [markdown]
# #**Components of Pandas**
#
#
# 1.   Series
# 2.   DataFrame

# %%
import pandas as pd

lst1 = [12,23,34,45,56,67,78,89,90,110]
sr1 = pd.Series(lst1)
sr1, sr1.ndim, type(sr1), sr1.size, sr1.dtype
# Out:
# (0     12
#  1     23
#  2     34
#  3     45
#  4     56
#  5     67
#  6     78
#  7     89
#  8     90
#  9    110
#  dtype: int64,
#  1,
#  pandas.core.series.Series,
#  10,
#  dtype('int64'))

# %%
tpl_one = (12, 23, 34, 45 ,56, 67 ,78, 89, 90)
tpl_one = pd.Series(tpl_one)
tpl_one, tpl_one.ndim, type(tpl_one), tpl_one.size, tpl_one.dtype
# Out:
# (0    12
#  1    23
#  2    34
#  3    45
#  4    56
#  5    67
#  6    78
#  7    89
#  8    90
#  dtype: int64,
#  1,
#  pandas.core.series.Series,
#  9,
#  dtype('int64'))

# %%
lst1 = [12,23,34,45,56,67,78,89,90,110]
sr1 = pd.Series(lst1)
sr1, len(sr1), sr1.count(), sr1.ndim, type(sr1), sr1.size, sr1.dtype, sr1.item, sr1.items, sr1.nbytes, sr1.shape

# %%
lst1 = [12,23,34,45,56,67,78,89,90,110]
print()
sr1 = pd.Series(lst1)
print(sr1)
print()
print('The length of the series is' ,len(sr1))
print()
print(sr1.count())
print()
print('The dimination of the series is',sr1.ndim)
print()
print('The type is ',type(sr1))
# Out:
# 0     12
# 1     23
# 2     34
# 3     45
# 4     56
# 5     67
# 6     78
# 7     89
# 8     90
# 9    110
# dtype: int64
#
# The length of the series is 10
#
# 10
#
# The dimination of the series is 1
#
# The type is  <class 'pandas.core.series.Series'>

# %%
tpl_one = (12, 23, 34, 45 ,56, 67 ,78, 89, 90)
tpl_one = pd.Series(tpl_one)

print(sr1.size,'\n')
print(sr1.dtype,'\n')
print(sr1.item,'\n')
print( sr1.items,'\n')
print(sr1.nbytes,'\n')
print(sr1.shape,'\n')
# Out:
# 10
#
# int64
#
# <bound method IndexOpsMixin.item of 0     12
# 1     23
# 2     34
# 3     45
# 4     56
# 5     67
# 6     78
# 7     89
# 8     90
# 9    110
# dtype: int64>
#
# <bound method Series.items of 0     12
# 1     23
# 2     34
# 3     45
# 4     56
# 5     67
# 6     78
# 7     89
# 8     90
# 9    110
# dtype: int64>
#
# 80
#
# (10,)
