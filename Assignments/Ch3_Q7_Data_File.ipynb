# %%
import pandas as pd

# %%
path = "/content/Ch3_Q7_Data_File.xlsx"

# %%
df = pd.read_excel(path)
df
# Out:
#     Rank           State  Life_Expectancy  Unnamed: 3  \
# 0      1          Hawaii             81.5         NaN
# 1      2       Minnesota             80.9         NaN
# 2      3      California             80.4         NaN
# 3      4        New York             80.4         NaN
# 4      5     Connecticut             80.2         NaN
# 5      6   Massachusetts             80.1         NaN
# 6      7    North Dakota             80.1         NaN
# 7      8            Utah             80.1         NaN
# 8      9        Colorado             79.9         NaN
# 9     10         Arizona             79.9         NaN
# 10    11    South Dakota             79.9         NaN
# 11    12   New Hampshire             79.7         NaN
# 12    13         Vermont             79.7         NaN
# 13    14         Florida             79.7         NaN
# 14    15            Iowa             79.7         NaN
# 15    16      New Jersey             79.7         NaN
# ...

# %%
df_cleaned = df.iloc[:, :3]
df_cleaned
# Out:
#     Rank           State  Life_Expectancy
# 0      1          Hawaii             81.5
# 1      2       Minnesota             80.9
# 2      3      California             80.4
# 3      4        New York             80.4
# 4      5     Connecticut             80.2
# 5      6   Massachusetts             80.1
# 6      7    North Dakota             80.1
# 7      8            Utah             80.1
# 8      9        Colorado             79.9
# 9     10         Arizona             79.9
# 10    11    South Dakota             79.9
# 11    12   New Hampshire             79.7
# 12    13         Vermont             79.7
# 13    14         Florida             79.7
# 14    15            Iowa             79.7
# 15    16      New Jersey             79.7
# 16    17      Washington             79.7
# 17    18       Wisconsin             79.3
# 18    19    Rhode Island             79.3
# 19    20           Idaho             79.2
# 20    21        Nebraska             79.2
# ...

# %%
df_cleaned.describe()
# Out:
#             Rank  Life_Expectancy
# count  50.000000        50.000000
# mean   25.600000        78.422000
# std    14.737153         1.640096
# min     1.000000        74.800000
# 25%    13.250000        77.525000
# 50%    25.500000        78.450000
# 75%    37.750000        79.700000
# max    51.000000        81.500000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['Rank'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
# ...

# %%
mean_Life_Expectancy = df_cleaned['Life_Expectancy'].mean()
round(mean_Life_Expectancy, 2)
# Out:
# 78.42

# %%
df_cleaned['Life_Expectancy'].median()
# Out:
# 78.45
