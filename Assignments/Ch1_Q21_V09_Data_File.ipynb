# %%
import pandas as pd

# %%
path = "/content/Ch1_Q21_V09_Data_File.xlsx"

# %%
df = pd.read_excel(path)

# %%
df.head()
# Out:
#    Observation        x1    x2  x3  x4  Unnamed: 5  Unnamed: 6  \
# 0            1       NaN   NaN   1   1         NaN         NaN
# 1            2  0.198204  78.0  23   3         NaN         NaN
# 2            3  0.889328  93.0  28   1         NaN         NaN
# 3            4  0.749451  69.0   3   2         NaN         NaN
# 4            5  0.177342  89.0  30   3         NaN         NaN
#
#                                           Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0                                                NaN        NaN        NaN
# 1  The accompanying data set contains three numer...        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3  a. How many observations have x4 values that a...        NaN        NaN
# 4                                                NaN        NaN        NaN
#
#   Unnamed: 10 Unnamed: 11
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# ...

# %%
df_cleaned = df.iloc[:,:5]

# %%
df_cleaned.head()
# Out:
#    Observation        x1    x2  x3  x4
# 0            1       NaN   NaN   1   1
# 1            2  0.198204  78.0  23   3
# 2            3  0.889328  93.0  28   1
# 3            4  0.749451  69.0   3   2
# 4            5  0.177342  89.0  30   3
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
(df_cleaned['x4'] < 3).sum()
# Out:
# 85

# %%
df_cleaned[df_cleaned['x4'] < 3].shape
# Out:
# (85, 5)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Observation  118 non-null    int64
#  1   x1           117 non-null    float64
#  2   x2           117 non-null    float64
#  3   x3           118 non-null    int64
#  4   x4           118 non-null    int64
# dtypes: float64(2), int64(3)
# memory usage: 4.7 KB

# %%
df_cleaned.sort_values('x1')
# Out:
#      Observation        x1     x2  x3  x4
# 5              6  0.012147   54.0  11   3
# 16            17  0.015640   21.0  25   2
# 102          103  0.019078   17.0  15   1
# 84            85  0.024693  197.0  25   1
# 63            64  0.036723  156.0  35   2
# ..           ...       ...    ...  ..  ..
# 72            73  0.913847  143.0   1   3
# 80            81  0.941049  159.0  31   1
# 86            87  0.973727  136.0  12   3
# 44            45  0.997994  196.0  13   3
# 0              1       NaN    NaN   1   1
#
# [118 rows x 5 columns]
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
df_cleaned.sort_values('x1', ascending= False)
# Out:
#      Observation        x1     x2  x3  x4
# 44            45  0.997994  196.0  13   3
# 86            87  0.973727  136.0  12   3
# 80            81  0.941049  159.0  31   1
# 72            73  0.913847  143.0   1   3
# 13            14  0.911021  153.0   9   1
# ..           ...       ...    ...  ..  ..
# 84            85  0.024693  197.0  25   1
# 102          103  0.019078   17.0  15   1
# 16            17  0.015640   21.0  25   2
# 5              6  0.012147   54.0  11   3
# 0              1       NaN    NaN   1   1
#
# [118 rows x 5 columns]
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
df_cleaned.isna().sum()
# Out:
# Observation    0
# x1             1
# x2             1
# x3             0
# x4             0
# dtype: int64

# %%
df_cleaned.head()
# Out:
#    Observation        x1    x2  x3  x4
# 0            1       NaN   NaN   1   1
# 1            2  0.198204  78.0  23   3
# 2            3  0.889328  93.0  28   1
# 3            4  0.749451  69.0   3   2
# 4            5  0.177342  89.0  30   3
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
df_cleaned['x4'].value_counts()
# Out:
# 2    45
# 1    40
# 3    33
# Name: x4, dtype: int64
