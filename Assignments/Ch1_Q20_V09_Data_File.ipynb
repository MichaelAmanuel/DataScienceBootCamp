# %%
import pandas as pd

# %%
path = "/content/Ch1_Q20_V12_Data_File.xlsx"

# %%
df = pd.read_excel(path)

# %%
df.head()
# Out:
#    Observation    x1     x2     x3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0            1  33.0  371.0  189.0         NaN         NaN         NaN
# 1            2  28.0  752.0    NaN         NaN         NaN         NaN
# 2            3  24.0  673.0  204.0         NaN         NaN         NaN
# 3            4  17.0    NaN  151.0         NaN         NaN         NaN
# 4            5  20.0   66.0  191.0         NaN         NaN         NaN
#
#                                           Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# 0                                                NaN        NaN         NaN
# 1                                                NaN        NaN         NaN
# 2  a. How many observations have x1 values greate...        NaN         NaN
# 3                                                NaN        NaN         NaN
# 4                            Number of abservations         NaN         NaN
#
#   Unnamed: 10 Unnamed: 11  Unnamed: 12  Unnamed: 13 Unnamed: 14
# ...

# %%
df_cleaned = df.iloc[:,:4]

# %%
df_cleaned
# Out:
#     Observation    x1     x2     x3
# 0             1  33.0  371.0  189.0
# 1             2  28.0  752.0    NaN
# 2             3  24.0  673.0  204.0
# 3             4  17.0    NaN  151.0
# 4             5  20.0   66.0  191.0
# ..          ...   ...    ...    ...
# 86           87  18.0  412.0  137.0
# 87           88  28.0  629.0  139.0
# 88           89  22.0  167.0  125.0
# 89           90  35.0  842.0  126.0
# 90           91  38.0  180.0  151.0
#
# [91 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %%
df_cleaned['x1'] > 30
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 86    False
# 87    False
# 88    False
# 89     True
# 90     True
# Name: x1, Length: 91, dtype: bool

# %%
(df_cleaned['x1'] > 30).sum()
# Out:
# 17

# %%
df_cleaned[df_cleaned['x1'] > 30]
# Out:
#     Observation    x1     x2     x3
# 0             1  33.0  371.0  189.0
# 6             7  37.0  596.0  187.0
# 11           12  39.0   62.0  128.0
# 15           16  37.0  207.0  213.0
# 19           20  36.0  842.0  141.0
# 33           34  39.0  173.0  160.0
# 35           36  43.0  768.0  140.0
# 37           38  34.0  677.0  167.0
# 38           39  31.0  688.0  146.0
# 39           40  38.0  735.0  143.0
# 45           46  41.0   71.0   94.0
# 54           55  36.0  540.0  211.0
# 69           70  57.0  218.0  154.0
# 74           75  33.0  564.0  178.0
# 77           78  33.0  966.0  163.0
# 89           90  35.0  842.0  126.0
# 90           91  38.0  180.0  151.0
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
df_cleaned[df_cleaned['x1'] > 30].shape
# Out:
# (17, 4)

# %%
df_cleaned.sort_values( 'x1', ascending= True)
# Out:
#     Observation    x1     x2     x3
# 50           51   2.0  335.0  166.0
# 58           59   4.0  257.0  144.0
# 40           41   6.0  992.0  150.0
# 16           17   6.0  999.0  156.0
# 81           82   7.0  430.0  160.0
# ..          ...   ...    ...    ...
# 11           12  39.0   62.0  128.0
# 45           46  41.0   71.0   94.0
# 35           36  43.0  768.0  140.0
# 69           70  57.0  218.0  154.0
# 20           21   NaN  850.0  162.0
#
# [91 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %%
df_cleaned.sort_values(by= 'x1', ascending= False )
# Out:
#     Observation    x1     x2     x3
# 69           70  57.0  218.0  154.0
# 35           36  43.0  768.0  140.0
# 45           46  41.0   71.0   94.0
# 11           12  39.0   62.0  128.0
# 33           34  39.0  173.0  160.0
# ..          ...   ...    ...    ...
# 40           41   6.0  992.0  150.0
# 16           17   6.0  999.0  156.0
# 58           59   4.0  257.0  144.0
# 50           51   2.0  335.0  166.0
# 20           21   NaN  850.0  162.0
#
# [91 rows x 4 columns]
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
df_cleaned.isnull().sum()
# Out:
# Observation    0
# x1             1
# x2             3
# x3             5
# dtype: int64
